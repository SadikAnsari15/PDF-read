# %%
import camelot
import pandas as pd

def process_bank_statement_one(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame (drop empty rows and columns)
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop irrelevant rows (based on the index, adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:111])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned



def process_bank_statement_classic(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 112 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:112])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned



def process_bank_statement_club_lloyds(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 127 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:127])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned



def process_bank_statement_standard_saver(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 138 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:138])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned


def process_bank_statement_standard_saver_2(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 138 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:138])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned


# 
def process_bank_statement(pdf_path):
    """
    Processes a bank statement PDF and returns a cleaned DataFrame.

    Parameters:
        pdf_path (str): Path to the PDF file.

    Returns:
        pd.DataFrame: Cleaned and structured DataFrame with relevant columns.
    """
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Drop any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)

    # Reset index and process DataFrame
    df_cleaned.reset_index(drop=True, inplace=True)

    # Remove unwanted initial rows (specific to this dataset)
    df = df_cleaned.drop(df_cleaned.index[:112])

    # Set the first row as the header (column names)
    df.columns = df.iloc[0]
    df = df[1:].reset_index(drop=True)

    # Define a helper function to check if a value is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Filter rows where the "Date" column contains valid dates
    df = df[df['Date'].apply(is_date)].reset_index(drop=True)

    # Drop the last column if not needed
    df = df.drop(df.columns[-1], axis=1)

    # Rename columns to standard names
    df = df.rename(columns={
        'Date': 'Date',
        'Payment type\nDetails': 'Description',
        'Money Out ([)': 'Withdraw',
        'Money In ([)': 'Credit',
        'Balance ([)': 'Balance',
        # Add more mappings if necessary
    })

    return df




# Example usage:
pdf_path = "left/Lloyds-bank-statement-standard-saver-2.pdf"
cleaned_df = process_bank_statement_standard_saver_2(pdf_path)
cleaned_df.head()


# Example usage:
pdf_path = "left/Lloyds-bank-statement-standard-saver-1.pdf"
cleaned_df = process_bank_statement_standard_saver(pdf_path)
cleaned_df.head()


# Example usage:
pdf_path = "left/Lloyds-bank-statement-club-lloyds-1.pdf"
cleaned_df = process_bank_statement_club_lloyds(pdf_path)
cleaned_df.head()


# Example usage:
pdf_path = "left/Lloyds-bank-statement-classic-1.pdf"
cleaned_df = process_bank_statement_classic(pdf_path)
cleaned_df.head()



# Example usage:
pdf_path = "left/Lloyds-bank-statement-basic-1.pdf"
cleaned_df = process_bank_statement_one(pdf_path)
cleaned_df.head()
# Out:
# 111       Date                          Description Withdraw Credit Balance
# 0    03 Dec 21            STATEMENT OPENING BALANCE                  485.56
# 1    06 Dec 21  TAPPILY\n04DEC21 SN3386516923022E2E           20.00  505.56
# 2    06 Dec 21       MARTIN MCCOLL CD 2817\n04DEC21    13.94         491.62
# 3    06 Dec 21         NETFLIX.COM CD 2817\n04DEC21    13.99         477.63
# 4    06 Dec 21  ASDA STORES LTD 58 CD 2817\n04DEC21    19.65         457.98

# %%
# Lloyds-bank-statement-basic-1

# %%
# Lloyds-bank-statement-basic-1

import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("left/Lloyds-bank-statement-basic-1.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)

df = df_cleaned
df = df.drop(df.index[:111])

# Set the first row as the header (column names)
df.columns = df.iloc[0]
# Remove the first row from the DataFrame
df = df[1:].reset_index(drop=True)

# Drop the 'Pmnt' column
df = df.drop(columns=['Pmnt'])

# Define a function to check if the value in the "Date" column is a valid date
def is_date(value):
    if pd.isna(value) or value == "":
        return False
    try:
        pd.to_datetime(value, format="%d %b %y", errors="raise")
        return True
    except ValueError:
        return False

# Apply the function to filter only rows where "Date" is a valid date and not empty
df = df[df['Date'].apply(is_date)]

# Reset index after filtering, if needed
df = df.reset_index(drop=True)

# Assuming df is your DataFrame
df = df.rename(columns={
    'Date': 'Date',
    'Details': 'Description',
    'Money Out (£)': 'Withdraw',
    'Money In (£)': 'Credit',
    'Balance (£)': 'Balance',
    # Add more columns as needed
})
# Out:
#                        0    1                                        2  \
# 0
# 1                                                  Statement number 11
# 2                                                           Issue date
# 3             MS H S WYE                                Write to us at
# 4    16 WILTSHIRE BARTON
# ..                   ...  ...                                      ...
# 224            31 Dec 21  FPO      MISS M NEWTON-WYE MUM 31DEC21 12:16
# 225            31 Dec 21  FPO  MR STEFAN J CROXAL HAYLEY 31DEC21 13:14
# 226            31 Dec 21  CPT          LNK ASDA FROME2 CD 2817 31DEC21
# 227            31 Dec 21  FPI               TAPPILY DF2136501974620700
# 228            31 Dec 21                     STATEMENT CLOSING BALANCE
#
#                     3         4       5
# 0         Page 1 of 5       NaN     NaN
# 1                           NaN     NaN
# 2    31 December 2021       NaN     NaN
# 3       Box 3 BX1 1LT       NaN     NaN
# 4                           NaN     NaN
# ..                ...       ...     ...
# 224            100.00            556.24
# 225             90.00            466.24
# 226             30.00            436.24
# 227                      100.00  536.24
# 228          2,291.36  2,342.04  536.24
#
# [229 rows x 6 columns]

# %%
# Lloyds-bank-statement-basic-1

import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("left/Lloyds-bank-statement-basic-1.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)

# %%
df = df_cleaned

# %%
df = df_cleaned
df = df.drop(df.index[:111])
df.head(20)
# Out:
#              0                 1                                    2  \
# 111       Date              Pmnt                              Details
# 112                         Type
# 113  03 Dec 21                              STATEMENT OPENING BALANCE
# 114  06 Dec 21               FPI  TAPPILY\n04DEC21 SN3386516923022E2E
# 115                                                LXZ1J23Y08M89VP9R4
# 116  06 Dec 21               DEB       MARTIN MCCOLL CD 2817\n04DEC21
# 117
# 118          K      Be ready for
# 119
# 120             changes when you
# 121
# 122          B
# 123                  shop online
# 124  06 Dec 21               DEB         NETFLIX.COM CD 2817\n04DEC21
# 125  06 Dec 21               DEB  ASDA STORES LTD 58 CD 2817\n04DEC21
# 126  06 Dec 21               DEB         RSS CHANDAG CD 2817\n04DEC21
# 127  06 Dec 21               DEB  ASDA STORES LTD 58 CD 2817\n04DEC21
# 128  06 Dec 21               DEB             TAPPILY CD 2817\n04DEC21
# 129  06 Dec 21               DEB    KING FISHER FISH CD 2817\n05DEC21
# 130  06 Dec 21               DEB    TESCO STORE 2880 CD 2817\n05DEC21
#
#                                                      3             4  \
# 111                                      Money Out (£)  Money In (£)
# 112
# 113
# 114                                                            20.00
# 115
# 116                                              13.94
# 117  Soon, you'll notice differences when you're sh...
# 118
# 119  haven't got your latest phone numbers, or you ...
# 120
# 121  purchases with your card may be declined. To u...
# 122
# 123  Find out more at lloydsbank.com/online-banking...
# 124                                              13.99
# 125                                              19.65
# 126                                              30.07
# 127                                             180.70
# 128                                             213.00
# 129                                              12.20
# 130                                              11.33
#
#                5
# 111  Balance (£)
# 112
# 113       485.56
# 114       505.56
# 115
# 116       491.62
# 117
# 118
# 119
# 120
# 121
# 122
# 123
# 124       477.63
# 125       457.98
# 126       427.91
# 127       247.21
# 128        34.21
# 129        22.01
# 130        10.68

# %%
# Set the first row as the header (column names)
df.columns = df.iloc[0]
# Remove the first row from the DataFrame
df = df[1:].reset_index(drop=True)

# %%
df
# Out:
# 111       Date  Pmnt                                  Details Money Out (£)  \
# 0               Type
# 1    03 Dec 21                      STATEMENT OPENING BALANCE
# 2    06 Dec 21   FPI      TAPPILY\n04DEC21 SN3386516923022E2E
# 3                                          LXZ1J23Y08M89VP9R4
# 4    06 Dec 21   DEB           MARTIN MCCOLL CD 2817\n04DEC21         13.94
# ..         ...   ...                                      ...           ...
# 112  31 Dec 21   FPO      MISS M NEWTON-WYE MUM 31DEC21 12:16        100.00
# 113  31 Dec 21   FPO  MR STEFAN J CROXAL HAYLEY 31DEC21 13:14         90.00
# 114  31 Dec 21   CPT          LNK ASDA FROME2 CD 2817 31DEC21         30.00
# 115  31 Dec 21   FPI               TAPPILY DF2136501974620700
# 116  31 Dec 21                      STATEMENT CLOSING BALANCE      2,291.36
#
# 111 Money In (£) Balance (£)
# 0
# 1                     485.56
# 2          20.00      505.56
# 3
# 4                     491.62
# ..           ...         ...
# 112                   556.24
# 113                   466.24
# 114                   436.24
# 115       100.00      536.24
# 116     2,342.04      536.24
#
# [117 rows x 6 columns]

# %%
# Drop the 'Pmnt' column
df = df.drop(columns=['Pmnt'])

# %%
# Define a function to check if the value in the "Date" column is a valid date
def is_date(value):
    if pd.isna(value) or value == "":
        return False
    try:
        pd.to_datetime(value, format="%d %b %y", errors="raise")
        return True
    except ValueError:
        return False

# Apply the function to filter only rows where "Date" is a valid date and not empty
df = df[df['Date'].apply(is_date)]

# Reset index after filtering, if needed
df = df.reset_index(drop=True)

# %%
df
# Out:
# 111       Date                                  Details Money Out (£)  \
# 0    03 Dec 21                STATEMENT OPENING BALANCE
# 1    06 Dec 21      TAPPILY\n04DEC21 SN3386516923022E2E
# 2    06 Dec 21           MARTIN MCCOLL CD 2817\n04DEC21         13.94
# 3    06 Dec 21             NETFLIX.COM CD 2817\n04DEC21         13.99
# 4    06 Dec 21      ASDA STORES LTD 58 CD 2817\n04DEC21         19.65
# ..         ...                                      ...           ...
# 81   31 Dec 21      MISS M NEWTON-WYE MUM 31DEC21 12:16        100.00
# 82   31 Dec 21  MR STEFAN J CROXAL HAYLEY 31DEC21 13:14         90.00
# 83   31 Dec 21          LNK ASDA FROME2 CD 2817 31DEC21         30.00
# 84   31 Dec 21               TAPPILY DF2136501974620700
# 85   31 Dec 21                STATEMENT CLOSING BALANCE      2,291.36
#
# 111 Money In (£) Balance (£)
# 0                     485.56
# 1          20.00      505.56
# 2                     491.62
# 3                     477.63
# 4                     457.98
# ..           ...         ...
# 81                    556.24
# 82                    466.24
# 83                    436.24
# 84        100.00      536.24
# 85      2,342.04      536.24
#
# [86 rows x 5 columns]

# %%
# Assuming df is your DataFrame
df = df.rename(columns={
    'Date': 'Date',
    'Details': 'Description',
    'Money Out (£)': 'Withdraw',
    'Money In (£)': 'Credit',
    'Balance (£)': 'Balance',
    # Add more columns as needed
})

# %%
file_path = "F:/python project/Lloyds-bank-statement-basic-1.csv"
df.to_csv(file_path, index=False)

# %%
import camelot
import pandas as pd

def process_bank_statement_classic(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 112 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:112])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned

# Example usage:
pdf_path = "left/Lloyds-bank-statement-classic-1.pdf"
cleaned_df = process_bank_statement_classic(pdf_path)
cleaned_df.head()
# Out:
# 112       Date                          Description Withdraw Credit Balance
# 0    01 Oct 21            STATEMENT OPENING BALANCE                    8.31
# 1    04 Oct 21          TOWNSEND T N TANIA\n02OCT21           50.00   58.31
# 2    04 Oct 21    K MORRIS\n02OCT21 309089 51561060    50.00           8.31
# 3    04 Oct 21    K MORRIS\n02OCT21 309089 51561060           35.00   43.31
# 4    04 Oct 21  PPOINT_*CLIFTON FO CD 5659\n02OCT21     2.29          41.02

# %%
# Lloyds-bank-statement-classic-1

import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("left/Lloyds-bank-statement-classic-1.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)
# Out:
#                    0    1                                  2                3  \
# 0                                                                 Page 1 of 7
# 1                                        Statement number 28
# 2                                                 Issue date  1 November 2021
# 3     MRS K N MORRIS                          Write to us at    Box 3 BX1 1LT
# 4    94 CLIFTON ROAD
# ..               ...  ...                                ...              ...
# 359        01 Nov 21  TFR  K MORRIS\n31OCT21 309089 51561060             2.00
# 360        01 Nov 21  TFR           K MORRIS 309089 51561060
# 361        01 Nov 21  DEB          SAINSBURYS S/MKTS CD 5659             0.21
# 362        01 Nov 21               STATEMENT CLOSING BALANCE         3,926.48
# 363   Payment types:
#
#             4     5
# 0         NaN   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN
# ..        ...   ...
# 359            0.23
# 360      1.00  1.23
# 361            1.02
# 362  3,919.19  1.02
# 363
#
# [364 rows x 6 columns]

# %%
df = df_cleaned
df = df.drop(df.index[:112])
df.head(20)
# Out:
#              0                 1                                    2  \
# 112       Date              Pmnt                              Details
# 113                         Type
# 114  01 Oct 21                              STATEMENT OPENING BALANCE
# 115  04 Oct 21               FPI          TOWNSEND T N TANIA\n02OCT21
# 116                                                RP4679961877514300
# 117  04 Oct 21               TFR    K MORRIS\n02OCT21 309089 51561060
# 118  04 Oct 21               TFR    K MORRIS\n02OCT21 309089 51561060
# 119  04 Oct 21               DEB  PPOINT_*CLIFTON FO CD 5659\n02OCT21
# 120
# 121          K      Be ready for
# 122
# 123             changes when you
# 124
# 125          B
# 126                  shop online
# 127  04 Oct 21               DEB   SAINSBURYS S/MKTS CD 5659\n02OCT21
# 128  04 Oct 21               TFR    K MORRIS\n02OCT21 309089 51561060
# 129  04 Oct 21               CPT   LNK TESCO THORNTON CD 5659 02OCT21
# 130  04 Oct 21               TFR    K MORRIS\n02OCT21 309089 51561060
# 131  04 Oct 21               TFR    K MORRIS\n02OCT21 309089 51561060
#
#                                                      3             4  \
# 112                                      Money Out (£)  Money In (£)
# 113
# 114
# 115                                                            50.00
# 116
# 117                                              50.00
# 118                                                            35.00
# 119                                               2.29
# 120  Soon, you'll notice differences when you're sh...
# 121
# 122  haven't got your latest phone numbers, or you ...
# 123
# 124  purchases with your card may be declined. To u...
# 125
# 126  Find out more at lloydsbank.com/online-banking...
# 127                                               3.50
# 128                                                             5.00
# 129                                              40.00
# 130                                                            15.00
# 131                                                             5.00
#
#                5
# 112  Balance (£)
# 113
# 114         8.31
# 115        58.31
# 116
# 117         8.31
# 118        43.31
# 119        41.02
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127        37.52
# 128        42.52
# 129         2.52
# 130        17.52
# 131        22.52

# %%
# Set the first row as the header (column names)
df.columns = df.iloc[0]
# Remove the first row from the DataFrame
df = df[1:].reset_index(drop=True)

# %%
# Drop the 'Pmnt' column
df = df.drop(columns=['Pmnt'])

# %%
# Define a function to check if the value in the "Date" column is a valid date
def is_date(value):
    if pd.isna(value) or value == "":
        return False
    try:
        pd.to_datetime(value, format="%d %b %y", errors="raise")
        return True
    except ValueError:
        return False

# Apply the function to filter only rows where "Date" is a valid date and not empty
df = df[df['Date'].apply(is_date)]

# Reset index after filtering, if needed
df = df.reset_index(drop=True)

# %%
# Assuming df is your DataFrame
df = df.rename(columns={
    'Date': 'Date',
    'Details': 'Description',
    'Money Out (£)': 'Withdraw',
    'Money In (£)': 'Credit',
    'Balance (£)': 'Balance',
    # Add more columns as needed
})

# %%
df
# Out:
# 112       Date                          Description  Withdraw    Credit  \
# 0    01 Oct 21            STATEMENT OPENING BALANCE
# 1    04 Oct 21          TOWNSEND T N TANIA\n02OCT21               50.00
# 2    04 Oct 21    K MORRIS\n02OCT21 309089 51561060     50.00
# 3    04 Oct 21    K MORRIS\n02OCT21 309089 51561060               35.00
# 4    04 Oct 21  PPOINT_*CLIFTON FO CD 5659\n02OCT21      2.29
# ..         ...                                  ...       ...       ...
# 199  01 Nov 21   SAINSBURYS S/MKTS CD 5659\n31OCT21      1.00
# 200  01 Nov 21    K MORRIS\n31OCT21 309089 51561060      2.00
# 201  01 Nov 21             K MORRIS 309089 51561060                1.00
# 202  01 Nov 21            SAINSBURYS S/MKTS CD 5659      0.21
# 203  01 Nov 21            STATEMENT CLOSING BALANCE  3,926.48  3,919.19
#
# 112 Balance
# 0      8.31
# 1     58.31
# 2      8.31
# 3     43.31
# 4     41.02
# ..      ...
# 199    2.23
# 200    0.23
# 201    1.23
# 202    1.02
# 203    1.02
#
# [204 rows x 5 columns]

# %%
file_path = "F:/python project/Lloyds-bank-statement-classic-1.csv"
df.to_csv(file_path, index=False)

# %%
import camelot
import pandas as pd

def process_bank_statement_club_lloyds(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 127 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:127])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned

# Example usage:
pdf_path = "left/Lloyds-bank-statement-club-lloyds-1.pdf"
cleaned_df = process_bank_statement_club_lloyds(pdf_path)
cleaned_df.head()
# Out:
# 127       Date                        Description Withdraw    Credit   Balance
# 0    19 Aug 21          STATEMENT OPENING BALANCE                         5.72
# 1    20 Aug 21                   100K84T0Z DWP UC           1,377.27  1,382.99
# 2    20 Aug 21             D HUNTER-REED FROM DEC              20.00  1,402.99
# 3    20 Aug 21  R PICKFORD FROM MUM 20AUG21 21:33    20.00            1,382.99
# 4    20 Aug 21                    TOMBOLA CD 1211              20.00  1,402.99

# %%
# Lloyds-bank-statement-club-lloyds-1

import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("left/Lloyds-bank-statement-club-lloyds-1.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)
# Out:
#                     0    1                          2                  3  \
# 0                                                            Page 1 of 5
# 1                                 Statement number 11
# 2                                          Issue date  17 September 2021
# 3    MRS H E PICKFORD                  Write to us at      Box 3 BX1 1LT
# 4          CREST BANK
# ..                ...  ...                        ...                ...
# 274         15 Sep 21  DEB     TESCO PFS 3424 CD 1211               0.70
# 275         15 Sep 21  DEB     TESCO PFS 3424 CD 1211              23.35
# 276         16 Sep 21  DEB     TESCO PFS 3424 CD 1211               2.95
# 277         17 Sep 21  DEB     TESCO PFS 3424 CD 1211              12.60
# 278         17 Sep 21       STATEMENT CLOSING BALANCE           2,424.84
#
#             4      5
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN
# ..        ...    ...
# 274            72.21
# 275            48.86
# 276            45.91
# 277            33.31
# 278  2,452.43  33.31
#
# [279 rows x 6 columns]

# %%
df = df_cleaned
df = df.drop(df.index[:127])
df.head(20)
# Out:
#              0                 1                                    2  \
# 127       Date              Pmnt                              Details
# 128                         Type
# 129  19 Aug 21                              STATEMENT OPENING BALANCE
# 130  20 Aug 21               BGC                     100K84T0Z DWP UC
# 131  20 Aug 21               FPI               D HUNTER-REED FROM DEC
# 132                                                300000000805867786
# 133  20 Aug 21               FPO    R PICKFORD FROM MUM 20AUG21 21:33
# 134  20 Aug 21               DEB                      TOMBOLA CD 1211
# 135
# 136          K      Be ready for
# 137
# 138             changes when you
# 139
# 140          B
# 141                  shop online
# 142  20 Aug 21               DEB                      TOMBOLA CD 1211
# 143  23 Aug 21               FPO    R PICKFORD FROM MUM 21AUG21 15:50
# 144  23 Aug 21               DEB       TOMBOLA.CO.UK CD 1211\n22AUG21
# 145  23 Aug 21               DEB       TOMBOLA.CO.UK CD 1211\n22AUG21
# 146  23 Aug 21               DEB  MARBLES MASTERCARD CD 1211\n22AUG21
#
#                                                      3             4  \
# 127                                      Money Out (£)  Money In (£)
# 128
# 129
# 130                                                         1,377.27
# 131                                                            20.00
# 132
# 133                                              20.00
# 134                                                            20.00
# 135  Soon, you'll notice differences when you're sh...
# 136
# 137  haven't got your latest phone numbers, or you ...
# 138
# 139  purchases with your card may be declined. To u...
# 140
# 141  Find out more at lloydsbank.com/online-banking...
# 142                                                            15.00
# 143                                              30.00
# 144                                              10.00
# 145                                              10.00
# 146                                               5.00
#
#                5
# 127  Balance (£)
# 128
# 129         5.72
# 130     1,382.99
# 131     1,402.99
# 132
# 133     1,382.99
# 134     1,402.99
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142     1,417.99
# 143     1,387.99
# 144     1,377.99
# 145     1,367.99
# 146     1,362.99

# %%
# Set the first row as the header (column names)
df.columns = df.iloc[0]
# Remove the first row from the DataFrame
df = df[1:].reset_index(drop=True)

# Drop the 'Pmnt' column
df = df.drop(columns=['Pmnt'])

# %%
# Define a function to check if the value in the "Date" column is a valid date
def is_date(value):
    if pd.isna(value) or value == "":
        return False
    try:
        pd.to_datetime(value, format="%d %b %y", errors="raise")
        return True
    except ValueError:
        return False

# Apply the function to filter only rows where "Date" is a valid date and not empty
df = df[df['Date'].apply(is_date)]

# Reset index after filtering, if needed
df = df.reset_index(drop=True)

# %%
# Assuming df is your DataFrame
df = df.rename(columns={
    'Date': 'Date',
    'Details': 'Description',
    'Money Out (£)': 'Withdraw',
    'Money In (£)': 'Credit',
    'Balance (£)': 'Balance',
    # Add more columns as needed
})

# %%
df
# Out:
# 127       Date                        Description  Withdraw    Credit  \
# 0    19 Aug 21          STATEMENT OPENING BALANCE
# 1    20 Aug 21                   100K84T0Z DWP UC            1,377.27
# 2    20 Aug 21             D HUNTER-REED FROM DEC               20.00
# 3    20 Aug 21  R PICKFORD FROM MUM 20AUG21 21:33     20.00
# 4    20 Aug 21                    TOMBOLA CD 1211               20.00
# ..         ...                                ...       ...       ...
# 113  15 Sep 21             TESCO PFS 3424 CD 1211      0.70
# 114  15 Sep 21             TESCO PFS 3424 CD 1211     23.35
# 115  16 Sep 21             TESCO PFS 3424 CD 1211      2.95
# 116  17 Sep 21             TESCO PFS 3424 CD 1211     12.60
# 117  17 Sep 21          STATEMENT CLOSING BALANCE  2,424.84  2,452.43
#
# 127   Balance
# 0        5.72
# 1    1,382.99
# 2    1,402.99
# 3    1,382.99
# 4    1,402.99
# ..        ...
# 113     72.21
# 114     48.86
# 115     45.91
# 116     33.31
# 117     33.31
#
# [118 rows x 5 columns]

# %%
file_path = "F:/python project/Lloyds-bank-statement-club-lloyds-1.csv"
df.to_csv(file_path, index=False)

# %%
import camelot
import pandas as pd

def process_bank_statement_standard_saver(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 138 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:138])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned

# Example usage:
pdf_path = "left/Lloyds-bank-statement-standard-saver-1.pdf"
cleaned_df = process_bank_statement_standard_saver(pdf_path)
cleaned_df.head()
# Out:
# 138       Date                       Description Withdraw Credit Balance
# 0    01 Oct 21         STATEMENT OPENING BALANCE                   20.00
# 1    04 Oct 21  D BUTLER 02OCT21 773308 33679260     5.00          15.00
# 2    04 Oct 21  D BUTLER 02OCT21 773308 33679260    15.00           0.00
# 3    04 Oct 21  D BUTLER 03OCT21 773308 33679260           13.90   13.90
# 4    04 Oct 21  D BUTLER 03OCT21 773308 33679260    13.00           0.90

# %%
# Lloyds-bank-statement-standard-saver-1

import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("left/Lloyds-bank-statement-standard-saver-1.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)
# Out:
#                    0    1                                 2                3  \
# 0                                                                Page 1 of 5
# 1                                       Statement number 30
# 2                                                Issue date  1 November 2021
# 3      MR D B BUTLER                         Write to us at    Box 3 BX1 1LT
# 4    7 COSGROVE WALK
# ..               ...  ...                               ...              ...
# 292        01 Nov 21  TFR  D BUTLER 30OCT21 773308 33679260            20.00
# 293        01 Nov 21  TFR  D BUTLER 30OCT21 773308 33679260            10.00
# 294        01 Nov 21  TFR          D BUTLER 773308 33679260
# 295        01 Nov 21  TFR          D BUTLER 773308 33679260            12.00
# 296        01 Nov 21              STATEMENT CLOSING BALANCE         2,115.30
#
#             4      5
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN
# ..        ...    ...
# 292            10.00
# 293             0.00
# 294     12.00  12.00
# 295             0.00
# 296  2,095.30   0.00
#
# [297 rows x 6 columns]

# %%
df = df_cleaned
df = df.drop(df.index[:138])
df.head(20)
# Out:
#              0     1                                 2              3  \
# 138       Date  Pmnt                           Details  Money Out (£)
# 139             Type
# 140  01 Oct 21               STATEMENT OPENING BALANCE
# 141  04 Oct 21   TFR  D BUTLER 02OCT21 773308 33679260           5.00
# 142  04 Oct 21   TFR  D BUTLER 02OCT21 773308 33679260          15.00
# 143  04 Oct 21   TFR  D BUTLER 03OCT21 773308 33679260
# 144  04 Oct 21   TFR  D BUTLER 03OCT21 773308 33679260          13.00
# 145  11 Oct 21   TFR          D BUTLER 773308 33679260
# 146  11 Oct 21   TFR          D BUTLER 773308 33679260          24.00
# 147  11 Oct 21   TFR          D BUTLER 773308 33679260          20.00
# 148  11 Oct 21   TFR          D BUTLER 773308 33679260
# 149  11 Oct 21   TFR          D BUTLER 773308 33679260          52.00
# 150  11 Oct 21   TFR          D BUTLER 773308 33679260          50.00
# 151  11 Oct 21   TFR          D BUTLER 773308 33679260          60.00
# 152  11 Oct 21   TFR          D BUTLER 773308 33679260          20.00
# 153  11 Oct 21   TFR          D BUTLER 773308 33679260
# 154  11 Oct 21   TFR          D BUTLER 773308 33679260          28.00
# 155  11 Oct 21   TFR          D BUTLER 773308 33679260          30.00
# 156  11 Oct 21   TFR          D BUTLER 773308 33679260          20.00
# 157  11 Oct 21   TFR          D BUTLER 773308 33679260          70.00
#
#                 4            5
# 138  Money In (£)  Balance (£)
# 139
# 140                      20.00
# 141                      15.00
# 142                       0.00
# 143         13.90        13.90
# 144                       0.90
# 145        264.00       264.90
# 146                     240.90
# 147                     220.90
# 148        500.00       720.90
# 149                     668.90
# 150                     618.90
# 151                     558.90
# 152                     538.90
# 153         20.00       558.90
# 154                     530.90
# 155                     500.90
# 156                     480.90
# 157                     410.90

# %%
# Set the first row as the header (column names)
df.columns = df.iloc[0]
# Remove the first row from the DataFrame
df = df[1:].reset_index(drop=True)

# Drop the 'Pmnt' column
df = df.drop(columns=['Pmnt'])

# %%
# Define a function to check if the value in the "Date" column is a valid date
def is_date(value):
    if pd.isna(value) or value == "":
        return False
    try:
        pd.to_datetime(value, format="%d %b %y", errors="raise")
        return True
    except ValueError:
        return False

# Apply the function to filter only rows where "Date" is a valid date and not empty
df = df[df['Date'].apply(is_date)]

# Reset index after filtering, if needed
df = df.reset_index(drop=True)

# %%
# Assuming df is your DataFrame
df = df.rename(columns={
    'Date': 'Date',
    'Details': 'Description',
    'Money Out (£)': 'Withdraw',
    'Money In (£)': 'Credit',
    'Balance (£)': 'Balance',
    # Add more columns as needed
})

# %%
df
# Out:
# 138       Date                       Description  Withdraw    Credit Balance
# 0    01 Oct 21         STATEMENT OPENING BALANCE                       20.00
# 1    04 Oct 21  D BUTLER 02OCT21 773308 33679260      5.00             15.00
# 2    04 Oct 21  D BUTLER 02OCT21 773308 33679260     15.00              0.00
# 3    04 Oct 21  D BUTLER 03OCT21 773308 33679260               13.90   13.90
# 4    04 Oct 21  D BUTLER 03OCT21 773308 33679260     13.00              0.90
# ..         ...                               ...       ...       ...     ...
# 139  01 Nov 21  D BUTLER 30OCT21 773308 33679260     20.00             10.00
# 140  01 Nov 21  D BUTLER 30OCT21 773308 33679260     10.00              0.00
# 141  01 Nov 21          D BUTLER 773308 33679260               12.00   12.00
# 142  01 Nov 21          D BUTLER 773308 33679260     12.00              0.00
# 143  01 Nov 21         STATEMENT CLOSING BALANCE  2,115.30  2,095.30    0.00
#
# [144 rows x 5 columns]

# %%
file_path = "F:/python project/Lloyds-bank-statement-standard-saver-1.csv"
df.to_csv(file_path, index=False)

# %%
import camelot
import pandas as pd

def process_bank_statement_standard_saver_2(pdf_path):
    # Step 1: Extract tables from all pages using the 'stream' flavor
    tables = camelot.read_pdf(pdf_path, pages="all", flavor="stream")

    # Step 2: Combine all tables into a single DataFrame
    dfs = [table.df for table in tables]
    df = pd.concat(dfs, ignore_index=True)

    # Step 3: Clean the DataFrame by dropping any empty rows or columns
    df_cleaned = df.dropna(how='all', axis=0)
    df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

    # Step 4: Reset index after cleaning
    df_cleaned.reset_index(drop=True, inplace=True)

    # Step 5: Drop the first 138 rows (adjust as needed)
    df_cleaned = df_cleaned.drop(df_cleaned.index[:138])

    # Step 6: Set the first row as the header (column names) and reset index
    df_cleaned.columns = df_cleaned.iloc[0]
    df_cleaned = df_cleaned[1:].reset_index(drop=True)

    # Step 7: Drop the 'Pmnt' column (if it exists)
    if 'Pmnt' in df_cleaned.columns:
        df_cleaned = df_cleaned.drop(columns=['Pmnt'])

    # Step 8: Define a function to check if the value in the "Date" column is a valid date
    def is_date(value):
        if pd.isna(value) or value == "":
            return False
        try:
            pd.to_datetime(value, format="%d %b %y", errors="raise")
            return True
        except ValueError:
            return False

    # Step 9: Filter rows where "Date" is a valid date
    df_cleaned = df_cleaned[df_cleaned['Date'].apply(is_date)]

    # Step 10: Reset the index after filtering
    df_cleaned = df_cleaned.reset_index(drop=True)

    # Step 11: Rename columns to standardize
    df_cleaned = df_cleaned.rename(columns={
        'Date': 'Date',
        'Details': 'Description',
        'Money Out (£)': 'Withdraw',
        'Money In (£)': 'Credit',
        'Balance (£)': 'Balance',
        # Add more columns as needed
    })

    return df_cleaned

# Example usage:
pdf_path = "left/Lloyds-bank-statement-standard-saver-2.pdf"
cleaned_df = process_bank_statement_standard_saver_2(pdf_path)
cleaned_df.head()
# Out:
# 138       Date                Description Withdraw Credit Balance
# 0    01 Sep 21  STATEMENT OPENING BALANCE                   10.47
# 1    02 Sep 21   D BUTLER 773308 33679260           24.00   34.47
# 2    02 Sep 21   D BUTLER 773308 33679260           30.00   64.47
# 3    02 Sep 21   D BUTLER 773308 33679260    14.00          50.47
# 4    02 Sep 21   D BUTLER 773308 33679260            7.00   57.47

# %%
# Lloyds-bank-statement-standard-saver-2

import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("left/Lloyds-bank-statement-standard-saver-2.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)
# Out:
#                    0    1                          2               3  \
# 0                                                        Page 1 of 6
# 1                                Statement number 29
# 2                                         Issue date  1 October 2021
# 3      MR D B BUTLER                  Write to us at   Box 3 BX1 1LT
# 4    7 COSGROVE WALK
# ..               ...  ...                        ...             ...
# 341        01 Oct 21  TFR   D BUTLER 773308 33679260          180.00
# 342        01 Oct 21  TFR   D BUTLER 773308 33679260
# 343        01 Oct 21  TFR   D BUTLER 773308 33679260
# 344        01 Oct 21       STATEMENT CLOSING BALANCE        1,884.35
# 345   Payment types:
#
#             4      5
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN
# ..        ...    ...
# 341             6.00
# 342      4.00  10.00
# 343     10.00  20.00
# 344  1,893.88  20.00
# 345
#
# [346 rows x 6 columns]

# %%
df = df_cleaned
df = df.drop(df.index[:138])
df.head(20)
# Out:
#              0     1                                 2              3  \
# 138       Date  Pmnt                           Details  Money Out (£)
# 139             Type
# 140  01 Sep 21               STATEMENT OPENING BALANCE
# 141  02 Sep 21   TFR          D BUTLER 773308 33679260
# 142  02 Sep 21   TFR          D BUTLER 773308 33679260
# 143  02 Sep 21   TFR          D BUTLER 773308 33679260          14.00
# 144  02 Sep 21   TFR          D BUTLER 773308 33679260
# 145  02 Sep 21   TFR          D BUTLER 773308 33679260           2.00
# 146  02 Sep 21   TFR          D BUTLER 773308 33679260           8.00
# 147  03 Sep 21   TFR          D BUTLER 773308 33679260          20.00
# 148  03 Sep 21   TFR          D BUTLER 773308 33679260
# 149  03 Sep 21   TFR          D BUTLER 773308 33679260          19.00
# 150  03 Sep 21   TFR          D BUTLER 773308 33679260          10.00
# 151  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260
# 152  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260           3.00
# 153  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260           4.00
# 154  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260
# 155  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260           4.50
# 156  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260           1.00
# 157  06 Sep 21   TFR  D BUTLER 04SEP21 773308 33679260          15.00
#
#                 4            5
# 138  Money In (£)  Balance (£)
# 139
# 140                      10.47
# 141         24.00        34.47
# 142         30.00        64.47
# 143                      50.47
# 144          7.00        57.47
# 145                      55.47
# 146                      47.47
# 147                      27.47
# 148          1.83        29.30
# 149                      10.30
# 150                       0.30
# 151         20.00        20.30
# 152                      17.30
# 153                      13.30
# 154         12.00        25.30
# 155                      20.80
# 156                      19.80
# 157                       4.80

# %%
# Set the first row as the header (column names)
df.columns = df.iloc[0]
# Remove the first row from the DataFrame
df = df[1:].reset_index(drop=True)

# Drop the 'Pmnt' column
df = df.drop(columns=['Pmnt'])

# %%
# Define a function to check if the value in the "Date" column is a valid date
def is_date(value):
    if pd.isna(value) or value == "":
        return False
    try:
        pd.to_datetime(value, format="%d %b %y", errors="raise")
        return True
    except ValueError:
        return False

# Apply the function to filter only rows where "Date" is a valid date and not empty
df = df[df['Date'].apply(is_date)]

# Reset index after filtering, if needed
df = df.reset_index(drop=True)

# %%
# Assuming df is your DataFrame
df = df.rename(columns={
    'Date': 'Date',
    'Details': 'Description',
    'Money Out (£)': 'Withdraw',
    'Money In (£)': 'Credit',
    'Balance (£)': 'Balance',
    # Add more columns as needed
})

# %%
df
# Out:
# 138       Date                Description  Withdraw    Credit Balance
# 0    01 Sep 21  STATEMENT OPENING BALANCE                       10.47
# 1    02 Sep 21   D BUTLER 773308 33679260               24.00   34.47
# 2    02 Sep 21   D BUTLER 773308 33679260               30.00   64.47
# 3    02 Sep 21   D BUTLER 773308 33679260     14.00             50.47
# 4    02 Sep 21   D BUTLER 773308 33679260                7.00   57.47
# ..         ...                        ...       ...       ...     ...
# 180  01 Oct 21   D BUTLER 773308 33679260                4.00  186.00
# 181  01 Oct 21   D BUTLER 773308 33679260    180.00              6.00
# 182  01 Oct 21   D BUTLER 773308 33679260                4.00   10.00
# 183  01 Oct 21   D BUTLER 773308 33679260               10.00   20.00
# 184  01 Oct 21  STATEMENT CLOSING BALANCE  1,884.35  1,893.88   20.00
#
# [185 rows x 5 columns]

# %%
file_path = "F:/python project/Lloyds-bank-statement-standard-saver-2.csv"
df.to_csv(file_path, index=False)
