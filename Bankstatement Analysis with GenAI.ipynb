# %% [markdown]
# # BankStatement Analysis with Gen AI
#
# ## Table of Contents
# 1. Introduction
# 2. Examples
# 3. References and Further Reading

# %% [markdown]
# <a id='2'></a>
#
# ## 1. Introduction
#
# Generative AI can be utilized in various ways for writing data engineering code, specifically for creating efficient and accurate data pipelines:
#
# 1. Code Generation: Automatically generating data engineering scripts based on high-level descriptions of tasks.
# 2. Optimization: Improving existing data engineering code based on performance feedback and best practices.
# 3. Schema Understanding: Interpreting data schemas to inform code generation and optimization.
# 4. Error Detection and Correction: Identifying and fixing errors in data engineering code through automated analysis.
# 5. Code Translation: Converting code between different programming languages and frameworks used in data engineering.
# 6. Complex Workflow Creation: Generating complex data workflows and pipelines based on user requirements.
# 7. Result Interpretation: Translating data processing results into human-readable reports and summaries.
# 8. Data Quality Checks: Generating code for validating data quality and consistency in pipelines.
# 9. Documentation Generation: Creating detailed documentation for data engineering code and workflows automatically.
#
# Using Gen AI for this task offers several benefits:
#
# - Increased productivity and efficiency for data engineers
# - Faster development and deployment of data pipelines
# - Reduced errors in code
# - Improved maintainability and readability of code

# %%
# !pip install openai
# !pip install pandas
# !pip install scikit-learn
# !pip install matplotlib
# Out:
# Requirement already satisfied: openai in c:\genai\resources\venv\lib\site-packages (1.43.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\genai\resources\venv\lib\site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\genai\resources\venv\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\genai\resources\venv\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\genai\resources\venv\lib\site-packages (from openai) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\genai\resources\venv\lib\site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in c:\genai\resources\venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\genai\resources\venv\lib\site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\genai\resources\venv\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\genai\resources\venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.8)
# Requirement already satisfied: certifi in c:\genai\resources\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\genai\resources\venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\genai\resources\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\genai\resources\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\genai\resources\venv\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: colorama in c:\genai\resources\venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Requirement already satisfied: pandas in c:\genai\resources\venv\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\genai\resources\venv\lib\site-packages (from pandas) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\genai\resources\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\genai\resources\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\genai\resources\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\genai\resources\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\genai\resources\venv\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\genai\resources\venv\lib\site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\genai\resources\venv\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\genai\resources\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\genai\resources\venv\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in c:\genai\resources\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (2.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\genai\resources\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\genai\resources\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import openai
import os
import json
import pandas as pd
from openai import OpenAI
import sklearn

# Set up OpenAI API key
client = OpenAI(api_key='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')

def clean(dict_variable):
    return next(iter(dict_variable.values()))

# %% [markdown]
# <a id='3'></a>
# ## 2. Example 1: Data cleaning

# %%
df = pd.read_csv('ApprovedCase.csv')

# %%
df
# Out:
#        Type                           Category       Description        Date  \
# 0    Credit              Salary/Regular Income               W.H  31-01-2022
# 1     Debit                    Uncategorisable               W.H  31-01-2022
# 2     Debit                    Uncategorisable               W.H  31-01-2022
# 3     Debit                    Uncategorisable               W.H  31-01-2022
# 4     Debit        General Stores, Superstores      TESCO STORES  31-01-2022
# ..      ...                                ...               ...         ...
# 841   Debit                Automotive Expenses           TT2 LTD  30-05-2022
# 842   Debit        General Stores, Superstores      TESCO STORES  30-05-2022
# 843   Debit            General Stores, General    NISA TYNEMOUTH  30-05-2022
# 844   Debit  Entertainment, Restaurants/Dining  COOPLANDS BAKERY  30-05-2022
# 845   Debit        General Stores, Superstores  CO-OP GROUP FOOD  30-05-2022
#
#      Credit  Debit  Running Balance
# 0     511.0   0.00           716.65
# 1       0.0  60.00           531.20
# 2       0.0  40.00           591.20
# 3       0.0  40.00           631.20
# 4       0.0  19.65           671.20
# ..      ...    ...              ...
# 841     0.0  31.90           111.79
# 842     0.0   3.84           143.69
# 843     0.0   4.29           174.53
# 844     0.0   3.00           178.82
# 845     0.0   0.60           181.82
#
# [846 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True)

# Extract the year and month for grouping
df['YearMonth'] = df['Date'].dt.to_period('M')

# Calculate disposable amount (Credit - Debit) for each month
monthly_disposable = df.groupby('YearMonth').apply(lambda x: x['Credit'].sum() - x['Debit'].sum(), include_groups=False)

# Convert the result to a DataFrame
monthly_disposable_df = monthly_disposable.reset_index(name='DisposableAmount')

print(monthly_disposable_df)
# Out:
#   YearMonth  DisposableAmount
# 0   2022-01          -2311.39
# 1   2022-02            -77.14
# 2   2022-03           6539.40
# 3   2022-04           2497.11
# 4   2022-05           1552.60

# %%
prompt = f"""Arrive at a decision to lend a finance based on the following data of a Customer.
{monthly_disposable_df}
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
)

result = response.choices[0].message.content
print(result)
# Out:
# To arrive at a decision regarding lending finance to the customer based on the provided data, we first need to analyze the "DisposableAmount" over the specified months.
#
# Here’s a breakdown of the provided data:
#
# - **January 2022**: -2311.39 (Deficit)
# - **February 2022**: -77.14 (Slight deficit)
# - **March 2022**: 6539.40 (Surplus)
# - **April 2022**: 2497.11 (Surplus)
# - **May 2022**: 1552.60 (Surplus)
#
# ### Analysis:
#
# 1. **Negative Disposable Amount in January and February**:
#    - The customer had a significant deficit in January and a minor one in February. This suggests potential cash flow issues during these months.
#
# 2. **Substantial Surplus in March**:
#    - In March, the customer experienced a significant surplus of 6539.40. This indicates a positive cash flow at this point, which is important for servicing any potential debt.
#
# 3. **Continued Surplus in April and May**:
#    - The customer maintained positive disposable amounts in April (2497.11) and May (1552.60). This trend indicates improved financial health following the deficits in the earlier months.
#
# ### Considerations:
#
# - **Trend Analysis**: While the two months of prior deficits may raise concerns, the subsequent recovery and the ability to generate a surplus are also crucial factors.
#
# - **Overall Cash Flow**: A closer look at the entire timeframe shows that the customer has transitioned from a deficit to a substantial surplus.
#
# - **Future Predictions**: Financial stability in the months following the deficits may suggest a resolution of prior cash flow issues, but it is essential to consider if the surplus is sustainable.
#
# - **Debt Servicing Ability**: The surpluses indicate that, currently, the customer has enough disposable income to manage debt repayments, but understanding whether this trend will continue is vital.
#
# ### Decision:
#
# Based on the provided information, the recommendation on lending finance would depend on additional factors, such as:
#
# - The amount requested for lending and repayment capacity.
# - A deeper understanding of the customer's overall financial picture (assets, liabilities).
# - Any potential fluctuations in expected income and expenses in future months.
#
# **If the application for finance is within the customer's ability to repay based on the positive outlook indicated by the March-May data**: **Progress towards a loan in a cautious manner, potentially after proposing terms that ensure they can manage monthly payments without returning to deficit.**
#
# However, if the applicant's income seems uncertain or lacking additional supporting documents, it might be advisable to **decline the loan or request further financial proof** to assess if the recent surpluses are likely to hold.

# %%
prompt = f"""Arrive a lending decision with status Approved,Declined or Deferred to Underwriter by reviewing the below data
{monthly_disposable_df} . Approve only if disposable Amount is more than 1000 for last 3 months, Decline if its less 1000 for all the months, Deferred to Underwriter if disposable amount is more than 1000 for 1 or more months.
"""

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": prompt}],
)

result = response.choices[0].message.content
print(result)
# Out:
# To arrive at a lending decision based on the provided criteria, we will analyze the `DisposableAmount` for the last three months (i.e., March, April, and May of 2022).
#
# Here are the relevant `DisposableAmount` values for the last three months:
#
# - **March 2022**: 6539.40
# - **April 2022**: 2497.11
# - **May 2022**: 1552.60
#
# Next, we evaluate these amounts against the conditions:
#
# 1. **Check if the disposable amounts are all greater than 1000**:
#    - March: 6539.40 (greater than 1000)
#    - April: 2497.11 (greater than 1000)
#    - May: 1552.60 (greater than 1000)
#
# Since all three months (March, April, May) have disposable amounts greater than 1000, the decision is:
#
# **Approved.**
