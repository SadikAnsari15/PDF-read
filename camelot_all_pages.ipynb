# %% [markdown]
# # Total pages

# %%
import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("Barclays-1.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)
# Out:
#                                                      0  \
# 0
# 1
# 2                                                    u
# 3
# 4
# ..                                                 ...
# 446  transactions the conversion may happen on the day
# 447  the transaction is processed. As this may be a...
# 448  two later, the exchange rate may be different ...
# 449                                               day.
# 450  You'll find a comparison of our exchange rate for
#
#                                                      1                 2    3  \
# 0                                              DL1 5YF
# 1                            Your accounts at a glance
# 2
# 3                         Your balances on 04 Jun 2021
# 4                                                       Everyday banking
# ..                                                 ...               ...  ...
# 446  and you’d like to, or if you do and you’d rath...                    NaN
# 447         didn’t, you can call 0345 7 345 345, go to                    NaN
# 448  barclays.co.uk, or come into a branch. And if you                    NaN
# 449   change your mind at any time, just get in touch.                    NaN
# 450                                                                       NaN
#
#        4
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ..   ...
# 446  NaN
# 447  NaN
# 448  NaN
# 449  NaN
# 450  NaN
#
# [451 rows x 5 columns]

# %%
df_cleaned = df_cleaned[df_cleaned[1].notna() & (df_cleaned[1] != "")]
df_cleaned.shape
# Out:
# (361, 5)

# %%
# Drop the top 10 rows and update the DataFrame in place
df_cleaned.drop(index=df_cleaned.index[:8], inplace=True)

# %%
df_cleaned.head(50)
# Out:
#                                             0  \
# 36                          Date\nDescription
# 38   05 May\nCard Payment to Uber *Eats On 04
# 40             Card Payment to Just Eat On 04
# 42         Card Payment to Fragrance Direct U
# 44                Card Payment to Co-Op Group
# 46                 Bill Payment to Mrs CL REA
# 53    06 May\nCard Payment to Amznmktplace On
# 55               Card Payment to W M Morrison
# 57          Card Payment to Domino S Pizza On
# 60                                       Date
# 61                                     06 May
# 62
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71                                     07 May
# 72
# 73                                     10 May
# 74
# 75
# 76
# 77
# 78
# 79
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
#
#                                       1          2         3         4
# 36                            Money out   Money in   Balance       NaN
# 38                                17.15                            NaN
# 40                                20.31                            NaN
# 42                                52.94                            NaN
# 44                                 8.35                            NaN
# 46                               550.00                            NaN
# 53                                16.27                            NaN
# 55                                21.42                            NaN
# 57                                31.88                            NaN
# 60                          Description  Money out  Money in   Balance
# 61   Card Payment to Birkenstock Digita     125.50
# 62                    Germany On 05 May
# 63          Card Payment to Co-Op Group       9.85
# 64                     108299 On 05 May
# 65         Card Payment to WM Morrisons      23.60
# 66                      Store On 05 May
# 67         Card Payment to WM Morrisons      27.79
# 68                      Store On 05 May
# 69         Received From Jade Edwardson                16.30  2,022.23
# 70                            Ref: Food
# 71       Card Payment to Www.Size.Co.UK      51.99            1,970.24
# 72                            On 06 May
# 73   Direct Debit to Animal Health Care      10.50
# 74                    Ref: HX0001010926
# 75   This Is A New Direct Debit Payment
# 76       Card Payment to Apple.Com/Bill       0.79
# 77                    Ireland On 09 May
# 78     Card Payment to Freeprints On 08       4.49
# 79                                  May
# 80      Card Payment to Amznmktplace On       6.99
# 81                               09 May
# 82       Card Payment to Just Eat On 07      11.20
# 83                                  May
# 84    Card Payment to Next Directory On      19.99
# 85                               09 May
# 86     Card Payment to Uber *Eats On 07      27.69
# 87                                  May
# 88      Card Payment to Deliveroo.Co.UK      29.93
# 89                            On 08 May
# 90     Card Payment to Dvla Vehicle Tax      30.00
# 91                            On 07 May
# 92       Card Payment to Write From The      59.48
# 93                        Hea On 09 May
# 94    Card Payment to Tesco Stores 2971      71.27
# 95                            On 08 May
# 96         Card Payment to WM Morrisons     105.91
# 97                      Store On 08 May
# 98         Card Payment to Www.Asos.Com     118.71
# 99                            On 08 May
# 100   Card Payment to Tesco Stores 2971       6.75

# %%
# Drop columns with index 6 and 7
df_cleaned = df_cleaned.drop([4], axis=1)

# Reset index if needed
df_cleaned.reset_index(drop=True, inplace=True)

# %%
df_cleaned.head(10)
df = df_cleaned

# %%
df = df[df[0].str.strip() != "Date"]
df
# Out:
#                                                      0  \
# 0                                    Date\nDescription
# 1             05 May\nCard Payment to Uber *Eats On 04
# 2                       Card Payment to Just Eat On 04
# 3                   Card Payment to Fragrance Direct U
# 4                          Card Payment to Co-Op Group
# ..                                                 ...
# 338         authorised.  However for a small number of
# 339  transactions the conversion may happen on the day
# 340  the transaction is processed. As this may be a...
# 341  two later, the exchange rate may be different ...
# 342                                               day.
#
#                                                      1         2        3
# 0                                            Money out  Money in  Balance
# 1                                                17.15
# 2                                                20.31
# 3                                                52.94
# 4                                                 8.35
# ..                                                 ...       ...      ...
# 338  Barclays accounts. If you don’t get these mess...                NaN
# 339  and you’d like to, or if you do and you’d rath...                NaN
# 340         didn’t, you can call 0345 7 345 345, go to                NaN
# 341  barclays.co.uk, or come into a branch. And if you                NaN
# 342   change your mind at any time, just get in touch.                NaN
#
# [337 rows x 4 columns]

# %%
# Specify new column names
new_column_names = ["Date/Description",  "Money Out", "Money In","Balance"]

# Assign new column names to the DataFrame
df.columns = new_column_names

# Optionally, drop any rows that are not needed (e.g., headers or footers)
df = df.drop(0).reset_index(drop=True)
df
# Out:
#                                       Date/Description  \
# 0             05 May\nCard Payment to Uber *Eats On 04
# 1                       Card Payment to Just Eat On 04
# 2                   Card Payment to Fragrance Direct U
# 3                          Card Payment to Co-Op Group
# 4                           Bill Payment to Mrs CL REA
# ..                                                 ...
# 331         authorised.  However for a small number of
# 332  transactions the conversion may happen on the day
# 333  the transaction is processed. As this may be a...
# 334  two later, the exchange rate may be different ...
# 335                                               day.
#
#                                              Money Out Money In Balance
# 0                                                17.15
# 1                                                20.31
# 2                                                52.94
# 3                                                 8.35
# 4                                               550.00
# ..                                                 ...      ...     ...
# 331  Barclays accounts. If you don’t get these mess...              NaN
# 332  and you’d like to, or if you do and you’d rath...              NaN
# 333         didn’t, you can call 0345 7 345 345, go to              NaN
# 334  barclays.co.uk, or come into a branch. And if you              NaN
# 335   change your mind at any time, just get in touch.              NaN
#
# [336 rows x 4 columns]

# %%
# Split the 'Date_Description' column into 'Date' and 'Description'
df[['Date', 'Description']] = df['Date/Description'].str.split('\n', expand=True)

# Drop the original 'Date_Description' column if needed
df.drop(columns=['Date/Description'], inplace=True)

# %%
df.head(20)
# Out:
#                              Money Out Money In Balance  \
# 0                                17.15
# 1                                20.31
# 2                                52.94
# 3                                 8.35
# 4                               550.00
# 5                                16.27
# 6                                21.42
# 7                                31.88
# 8   Card Payment to Birkenstock Digita   125.50
# 9                    Germany On 05 May
# 10         Card Payment to Co-Op Group     9.85
# 11                    108299 On 05 May
# 12        Card Payment to WM Morrisons    23.60
# 13                     Store On 05 May
# 14        Card Payment to WM Morrisons    27.79
# 15                     Store On 05 May
# 16        Received From Jade Edwardson            16.30
# 17                           Ref: Food
# 18      Card Payment to Www.Size.Co.UK    51.99
# 19                           On 06 May
#
#                                   Date                       Description
# 0                               05 May  Card Payment to Uber *Eats On 04
# 1       Card Payment to Just Eat On 04                              None
# 2   Card Payment to Fragrance Direct U                              None
# 3          Card Payment to Co-Op Group                              None
# 4           Bill Payment to Mrs CL REA                              None
# 5                               06 May   Card Payment to Amznmktplace On
# 6         Card Payment to W M Morrison                              None
# 7    Card Payment to Domino S Pizza On                              None
# 8                               06 May                              None
# 9                                                                   None
# 10                                                                  None
# 11                                                                  None
# 12                                                                  None
# 13                                                                  None
# 14                                                                  None
# 15                                                                  None
# 16                                                                  None
# 17                                                                  None
# 18                              07 May                              None
# 19                                                                  None

# %%
df = df_cleaned.drop(0).reset_index(drop=True)
df
# Out:
#               0                   1      2                         3  \
# 0         Date.        Description.  Type.             Money In (£).
# 1          Date         Description   Type
# 2    01 Jul 21.  TESCO PAY AT PUMP.   DEB.
# 3          Date         Description   Type
# 4    01 Jul 21.        LIDL GB AYR.   DEB.
# ..          ...                 ...    ...                       ...
# 608  30 Jul 21.       DAILY OD INT.   CHG.
# 609        BGC.   Bank Giro Credit.    BP.            Bill Payments.
# 610        DEP.            Deposit.   FEE.             Fixed Service
# 611        MPI.  Mobile Payment In.         MPO. Mobile Payment Out.
# 612        TFR.           Transfer.
#
#                             4             5
# 0              Money Out (£).  Balance (£).
# 1               Money Out (£)   Balance (£)
# 2                      40.00.      -311.39.
# 3               Money Out (£)   Balance (£)
# 4                       3.65.      -315.04.
# ..                        ...           ...
# 608                     0.33.      -299.54.
# 609              CHG. Charge.
# 610  FPI.\nFaster Payment In.          FPO.
# 611            PAY.\nPayment.           SO.
# 612
#
# [613 rows x 6 columns]

# %%
df = df[df[0].str.strip() != "Date"]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = df[df[0].str.strip() != "Date"]
#       2 df
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 0

# %%
# Set the first row as column names
df.columns = df.iloc[0]

# Drop the first row
df = df[1:]

# Reset index
df.reset_index(drop=True, inplace=True)

# Clean any leading or trailing spaces in column names
df.columns = df.columns.str.strip()

# %%
df
# Out:
# 0    01 Jul 21.  TESCO PAY AT PUMP.  DEB.                            \
# 0    01 Jul 21.        LIDL GB AYR.  DEB.
# 1    01 Jul 21.         GREGGS PLC.  DEB.
# 2    01 Jul 21.  PPOINT_*WOODFIELD.  DEB.
# 3    01 Jul 21.     TESCO PFS 4143.  DEB.
# 4    01 Jul 21.     TESCO PFS 3701.  DEB.
# ..          ...                 ...   ...                       ...
# 314  30 Jul 21.       DAILY OD INT.  CHG.
# 315        BGC.   Bank Giro Credit.   BP.            Bill Payments.
# 316        DEP.            Deposit.  FEE.             Fixed Service
# 317        MPI.  Mobile Payment In.        MPO. Mobile Payment Out.
# 318        TFR.           Transfer.
#
# 0                      40.00.  -311.39.
# 0                       3.65.  -315.04.
# 1                       5.90.  -320.94.
# 2                       7.36.  -328.30.
# 3                      11.45.  -339.75.
# 4                      13.25.  -353.00.
# ..                        ...       ...
# 314                     0.33.  -299.54.
# 315              CHG. Charge.
# 316  FPI.\nFaster Payment In.      FPO.
# 317            PAY.\nPayment.       SO.
# 318
#
# [319 rows x 6 columns]

# %%
# Specify new column names
new_column_names = ["Date", "Description", "Type", "Money In", "Money Out", "Balance"]

# Assign new column names to the DataFrame
df.columns = new_column_names

# Optionally, drop any rows that are not needed (e.g., headers or footers)
df = df.drop(0).reset_index(drop=True)
df
# Out:
#            Date         Description  Type                  Money In  \
# 0    01 Jul 21.         GREGGS PLC.  DEB.
# 1    01 Jul 21.  PPOINT_*WOODFIELD.  DEB.
# 2    01 Jul 21.     TESCO PFS 4143.  DEB.
# 3    01 Jul 21.     TESCO PFS 3701.  DEB.
# 4    01 Jul 21.         EE LIMITED.  DEB.
# ..          ...                 ...   ...                       ...
# 313  30 Jul 21.       DAILY OD INT.  CHG.
# 314        BGC.   Bank Giro Credit.   BP.            Bill Payments.
# 315        DEP.            Deposit.  FEE.             Fixed Service
# 316        MPI.  Mobile Payment In.        MPO. Mobile Payment Out.
# 317        TFR.           Transfer.
#
#                     Money Out   Balance
# 0                       5.90.  -320.94.
# 1                       7.36.  -328.30.
# 2                      11.45.  -339.75.
# 3                      13.25.  -353.00.
# 4                      80.00.  -433.00.
# ..                        ...       ...
# 313                     0.33.  -299.54.
# 314              CHG. Charge.
# 315  FPI.\nFaster Payment In.      FPO.
# 316            PAY.\nPayment.       SO.
# 317
#
# [318 rows x 6 columns]

# %%
# Remove rows where column 0 has the value "Date" (with inplace=True)
df.drop(df[df['Date'].str.strip() == "Date."].index, inplace=True)
df.drop(df[df['Date'].str.strip() == "Date."].index, inplace=True)
df.drop(df[df['Date'].str.strip() == "Column"].index, inplace=True)
df.drop(df[df['Money In'].str.strip() == "Money In (£)\nblank."].index, inplace=True)
df.drop(df[df['Money Out'].str.strip() == "Money Out (£)\nblank."].index, inplace=True)
# Reset the index to maintain continuous indexing after dropping rows
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#            Date         Description  Type                  Money In  \
# 0    01 Jul 21.         GREGGS PLC.  DEB.
# 1    01 Jul 21.  PPOINT_*WOODFIELD.  DEB.
# 2    01 Jul 21.     TESCO PFS 4143.  DEB.
# 3    01 Jul 21.     TESCO PFS 3701.  DEB.
# 4    01 Jul 21.         EE LIMITED.  DEB.
# ..          ...                 ...   ...                       ...
# 289  30 Jul 21.       DAILY OD INT.  CHG.
# 290        BGC.   Bank Giro Credit.   BP.            Bill Payments.
# 291        DEP.            Deposit.  FEE.             Fixed Service
# 292        MPI.  Mobile Payment In.        MPO. Mobile Payment Out.
# 293        TFR.           Transfer.
#
#                     Money Out   Balance
# 0                       5.90.  -320.94.
# 1                       7.36.  -328.30.
# 2                      11.45.  -339.75.
# 3                      13.25.  -353.00.
# 4                      80.00.  -433.00.
# ..                        ...       ...
# 289                     0.33.  -299.54.
# 290              CHG. Charge.
# 291  FPI.\nFaster Payment In.      FPO.
# 292            PAY.\nPayment.       SO.
# 293
#
# [294 rows x 6 columns]

# %%
# Function to clean trailing periods from numerical values
def clean_numeric_values(value):
    if isinstance(value, str):
        return value.strip('.')
    return value

# Apply the cleaning function to relevant columns
columns_to_clean = ["Money In", "Money Out", "Balance"]
for column in columns_to_clean:
    df[column] = df[column].apply(clean_numeric_values)

# Convert columns to numeric types if needed
df["Money In"] = pd.to_numeric(df["Money In"], errors='coerce')
df["Money Out"] = pd.to_numeric(df["Money Out"], errors='coerce')
df["Balance"] = pd.to_numeric(df["Balance"], errors='coerce')

# %%
df.tail(5)
# Out:
#            Date         Description  Type  Money In  Money Out  Balance
# 289  30 Jul 21.       DAILY OD INT.  CHG.       NaN       0.33  -299.54
# 290        BGC.   Bank Giro Credit.   BP.       NaN        NaN      NaN
# 291        DEP.            Deposit.  FEE.       NaN        NaN      NaN
# 292        MPI.  Mobile Payment In.             NaN        NaN      NaN
# 293        TFR.           Transfer.             NaN        NaN      NaN

# %%
# Function to validate and convert dates
def is_valid_date(date_str):
    try:
        pd.to_datetime(date_str, format='%d %b %y')
        return True
    except ValueError:
        return False

# Remove trailing periods and check date validity
df['Date'] = df['Date'].str.replace('.', '', regex=False)
df['Date_valid'] = df['Date'].apply(is_valid_date)

# Filter out rows with invalid dates
df = df[df['Date_valid']].drop(columns='Date_valid')
df.tail(10)
#df.shape
# Out:
#           Date          Description  Type  Money In  Money Out  Balance
# 280  29 Jul 21  SUBWAY 32619 Carri.  DEB.       NaN      12.57  -349.65
# 281  29 Jul 21        DAILY OD INT.  CHG.       NaN       0.38  -350.03
# 282  30 Jul 21           J THOMSON.  TFR.     80.00        NaN  -270.03
# 283  30 Jul 21           J THOMSON.  TFR.       NaN      80.00  -350.03
# 284  30 Jul 21  BROOKSON SOLUTIONS.  FPI.    969.39        NaN   619.36
# 285  30 Jul 21           J THOMSON.  TFR.     90.00        NaN   709.36
# 286  30 Jul 21           J THOMSON.  TFR.       NaN        NaN  -369.22
# 287  30 Jul 21  PAYPAL *APPLE.COM/.  DEB.       NaN       7.99  -377.21
# 288  30 Jul 21           J THOMSON.  TFR.     78.00        NaN  -299.21
# 289  30 Jul 21        DAILY OD INT.  CHG.       NaN       0.33  -299.54

# %%
import pandas as pd

# %%
df = pd.read_csv("F:/python project/pdf1.csv")

# %%
from openai import OpenAI 
import os 
import requests 
from pdf2image import convert_from_bytes 
from PIL import Image 
import base64 
import json
import pytesseract
from io import BytesIO 
import pandas as pd

# %%
# Initialize OpenAI client
client = OpenAI(api_key='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')

# Get the completion from the model
response = client.chat.completions.create(
    model="gpt-4o-mini",  # Ensure you have the correct model name
    messages=[{"role": "user", "content": prompt}],
)
result = response.choices[0].message.content
print(result)
# Out:
# To arrive at a lending decision based on the provided data, we need to first determine the disposable amount for the last 3 months. The disposable amount can be computed using the balance and the money out amounts.
#
# Here is how we would assess the data:
#
# 1. **Calculate Disposable Amount:** For each month, the disposable amount can be understood as the money available after expenses. We will need to subtract the total money out for that month from the ending balance for the month.
#
# 2. **Check Conditions:**
#    - Approve if the disposable amount is more than 1000 for all three months.
#    - Decline if the disposable amount is less than 1000 for all three months.
#    - Defer to Underwriter if the disposable amount is more than 1000 for one or more months.
#
# Let’s summarize the last three months from the data:
#
# 1. **April 2021** (assuming the data includes all transactions):
#    - Total money out = sum of all out transactions for April
#    - Ending balance = the last balance number for April.
#
# 2. **May 2021:**
#    - Total money out = sum of all out transactions for May
#    - Ending balance = the last balance number for May.
#
# 3. **June 2021:**
#    - Total money out = sum of all out transactions for June
#    - Ending balance = the last balance number for June.
#
# After calculating these amounts:
#
# - **April Disposable Amount:** (Ending Balance Apr) - (Total Money Out Apr)
# - **May Disposable Amount:** (Ending Balance May) - (Total Money Out May)
# - **June Disposable Amount:** (Ending Balance June) - (Total Money Out June)
#
# Now, let’s determine the lending decision based on these disposable amounts:
#
# - If all three months' disposable amounts are > 1000: **Approved**
# - If all three months' disposable amounts are < 1000: **Declined**
# - If one or more months' disposable amounts are > 1000: **Deferred to Underwriter**
#
# ### Final Decision:
# Based on the calculations (which would require the actual amount records and balances from the dataset), you will conclude to either Approved, Declined, or Deferred to Underwriter.
#
# You would implement these steps programmatically or use spreadsheet calculations to find the actual values if working with a dataset.

# %%
df = df.fillna('')

# %%
file_path = "F:/python project/pdf2.csv"

# %%
#df.to_csv(file_path, index=False)
