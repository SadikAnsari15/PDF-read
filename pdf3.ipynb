# %%
import camelot
import pandas as pd

# Extract tables from all pages using the 'stream' flavor
tables = camelot.read_pdf("Bank-of-Scotland-classic-vantage-3.pdf", pages="all", flavor="stream")

# Combine all tables into a single DataFrame
dfs = [table.df for table in tables]
df = pd.concat(dfs, ignore_index=True)

# Drop any empty rows or columns if needed
df_cleaned = df.dropna(how='all', axis=0)
df_cleaned = df_cleaned.dropna(how='all', axis=1)  # Optionally drop empty columns

# Reset index and print the cleaned DataFrame
df_cleaned.reset_index(drop=True, inplace=True)
print(df_cleaned)
# Out:
#                                                      0                   1  \
# 0                                               Column              Column
# 1                                                Date.        Description.
# 2                                                 Date         Description
# 3
# 4                                           02 Jun 21.  REPORTCURVE.CO.UK.
# ..                                                 ...                 ...
# 135  If you think something is incorrect, please co...
# 136  Bank of Scotland plc is registered in Scotland...
# 137  Prudential Regulation Authority and regulated ...
# 138  registration no. 169628. We adhere to The Stan...
# 139                   www.lendingstandardsboard.org.uk
#
#           2                     3               4             5    6    7
# 0    Column                Column          Column        Column  NaN  NaN
# 1     Type.         Money In (£).  Money Out (£).  Balance (£).  NaN  NaN
# 2      Type                         Money Out (£)   Balance (£)  NaN  NaN
# 3            Money In (£)\nblank.                                NaN  NaN
# 4      DEB.                                 0.11.       -42.91.  NaN  NaN
# ..      ...                   ...             ...           ...  ...  ...
# 135
# 136
# 137
# 138
# 139
#
# [140 rows x 8 columns]

# %%
df_cleaned = df_cleaned[df_cleaned[1].notna() & (df_cleaned[1] != "")]
df = df_cleaned.drop(0).reset_index(drop=True)
df
# Out:
#              0                    1      2                         3  \
# 0        Date.         Description.  Type.             Money In (£).
# 1         Date          Description   Type
# 2   02 Jun 21.   REPORTCURVE.CO.UK.   DEB.
# 3         Date          Description   Type              Money In (£)
# 4   16 Jun 21.  DUMFRIES HIGH ST (.   DEP.                   727.28.
# ..         ...                  ...    ...                       ...
# 82  30 Jun 21.      CONNOR GRIFFIN.   FPO.
# 83        BGC.    Bank Giro Credit.    BP.            Bill Payments.
# 84        DEP.             Deposit.   FEE.             Fixed Service
# 85        MPI.   Mobile Payment In.         MPO. Mobile Payment Out.
# 86        TFR.            Transfer.
#
#                            4             5                6  \
# 0             Money Out (£).  Balance (£).              NaN
# 1              Money Out (£)   Balance (£)              NaN
# 2                      0.11.       -42.91.              NaN
# 3                              Balance (£)              NaN
# 4                                  684.37.              NaN
# ..                       ...           ...              ...
# 82                    17.00.         0.19.              NaN
# 83              CHG. Charge.                   CHQ. Cheque.
# 84  FPI.\nFaster Payment In.          FPO.
# 85            PAY.\nPayment.           SO.  Standing Order.
# 86
#
#                       7
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 82                  NaN
# 83
# 84  Faster Payment Out.
# 85
# 86
#
# [87 rows x 8 columns]

# %%
# Drop columns with index 6 and 7
df = df.drop([6,7], axis=1)

# Reset index if needed
df.reset_index(drop=True, inplace=True)

# %%
df = df[df[0].str.strip() != "Date"]
# Set the first row as column names
df.columns = df.iloc[0]

# Drop the first row
df = df[1:]

# Reset index
df.reset_index(drop=True, inplace=True)

# Clean any leading or trailing spaces in column names
df.columns = df.columns.str.strip()

# %%
df
# Out:
# 0        Date.         Description.   Type.             Money In (£).  \
# 0   02 Jun 21.   REPORTCURVE.CO.UK.    DEB.
# 1   16 Jun 21.  DUMFRIES HIGH ST (.    DEP.                   727.28.
# 2   17 Jun 21.      CONNOR GRIFFIN.    FPO.
# 3   17 Jun 21.      CONNOR GRIFFIN.    FPO.
# 4   18 Jun 21.          LEE CURRIE.    FPO.
# 5   18 Jun 21.       Sweet Sadie s.    DEB.
# 6   18 Jun 21.        NEW ORIENTAL.    DEB.
# 7   18 Jun 21.  ST MICHAELS SERVIC.    DEB.
# 8   18 Jun 21.          LEE CURRIE.    FPO.
# 9   18 Jun 21.          LEE CURRIE.    FPI.                    50.00.
# 10  18 Jun 21.         LNK BGL LTD.    CPT.
# 11  18 Jun 21.          LEE CURRIE.    FPI.                    50.00.
# 12  18 Jun 21.         LNK BGL LTD.    CPT.
# 13  18 Jun 21.          LEE CURRIE.    FPI.                    30.00.
# 14  18 Jun 21.         LNK BGL LTD.    CPT.
# 15  18 Jun 21.          LEE CURRIE.    FPI.                    30.00.
# 16  18 Jun 21.         LNK BGL LTD.    CPT.
# 17      Column               Column  Column                    Column
# 18       Date.         Description.   Type.             Money In (£).
# 19  21 Jun 21.  LEE CURRIE 19JUN21.    FPI.                   112.00.
# 20  21 Jun 21.  LNK CHURCH CRESCEN.    CPT.
# 21  21 Jun 21.              GREGGS.    DEB.
# 22  21 Jun 21.  WWW.PAYMENT-ASSIST.    DEB.
# 23  21 Jun 21.  SUMUP  *HELPINGHAN.    DEB.
# 24  21 Jun 21.  LNK DUMFRIES WHITE.    CPT.
# 25  21 Jun 21.      KFC - DUMFRIES.    DEB.
# 26  21 Jun 21.   TESCO STORES 2388.    DEB.
# 27  21 Jun 21.       CASTLE FRYERY.    DEB.
# 28  21 Jun 21.          DEAN POTTS.    FPO.
# 29  21 Jun 21.          LEE CURRIE.    FPI.                   250.00.
# 30  21 Jun 21.          DEAN POTTS.    FPO.
# 31  21 Jun 21.          DEAN POTTS.    FPO.
# 32  21 Jun 21.         LNK BGL LTD.    CPT.
# 33  22 Jun 21.  TESCO PAYAT PUMP 4.    DEB.
# 34  22 Jun 21.            CARLISLE.    DEB.
# 35  22 Jun 21.            CARLISLE.    DEB.
# 36  23 Jun 21.    MARCHBANK BAKERS.    DEB.
# 37  24 Jun 21.   REPORTCURVE.CO.UK.    DEB.
# 38  28 Jun 21.          TUI UK LTD.     DD.
# 39  28 Jun 21.         RETURNED DD.                           149.45.
# 40  30 Jun 21.          LEE CURRIE.    FPI.                    12.00.
# 41  30 Jun 21.      CONNOR GRIFFIN.    FPO.
# 42        BGC.    Bank Giro Credit.     BP.            Bill Payments.
# 43        DEP.             Deposit.    FEE.             Fixed Service
# 44        MPI.   Mobile Payment In.          MPO. Mobile Payment Out.
# 45        TFR.            Transfer.
#
# 0             Money Out (£).  Balance (£).
# 0                      0.11.       -42.91.
# 1                                  684.37.
# 2                     10.00.       674.37.
# 3                     10.00.       664.37.
# 4                     15.00.       649.37.
# 5                     10.80.       638.57.
# 6                     11.30.       627.27.
# 7                     52.94.       574.33.
# 8                    409.00.       165.33.
# 9                                  215.33.
# 10                    50.00.       165.33.
# 11                                 215.33.
# 12                    50.00.       165.33.
# 13                                 195.33.
# 14                    30.00.       165.33.
# 15                                 195.33.
# 16                    30.00.       165.33.
# 17                    Column        Column
# 18            Money Out (£).  Balance (£).
# 19                                 277.33.
# 20                    10.00.       267.33.
# 21                     5.75.       261.58.
# 22                    60.08.       201.50.
# 23                    70.00.       131.50.
# 24                    60.00.        71.50.
# 25                     7.10.        64.40.
# 26                    10.48.        53.92.
# 27                    13.50.        40.42.
# 28                    10.00.        30.42.
# 29                                 280.42.
# 30                    30.00.       250.42.
# 31                    10.00.       240.42.
# 32                    30.00.       210.42.
# 33                    37.18.       173.24.
# 34                    40.00.       133.24.
# 35                    94.00.        39.24.
# 36                     4.80.        34.44.
# 37                    29.25.         5.19.
# 38                   149.45.      -144.26.
# 39                                   5.19.
# 40                                  17.19.
# 41                    17.00.         0.19.
# 42              CHG. Charge.
# 43  FPI.\nFaster Payment In.          FPO.
# 44            PAY.\nPayment.           SO.
# 45

# %%
# Specify new column names
new_column_names = ["Date", "Description", "Type", "Money In", "Money Out", "Balance"]

# Assign new column names to the DataFrame
df.columns = new_column_names

# Optionally, drop any rows that are not needed (e.g., headers or footers)
df = df.drop(0).reset_index(drop=True)
df.head(10)
# Out:
#          Date          Description  Type Money In Money Out  Balance
# 0  16 Jun 21.  DUMFRIES HIGH ST (.  DEP.  727.28.            684.37.
# 1  17 Jun 21.      CONNOR GRIFFIN.  FPO.             10.00.  674.37.
# 2  17 Jun 21.      CONNOR GRIFFIN.  FPO.             10.00.  664.37.
# 3  18 Jun 21.          LEE CURRIE.  FPO.             15.00.  649.37.
# 4  18 Jun 21.       Sweet Sadie s.  DEB.             10.80.  638.57.
# 5  18 Jun 21.        NEW ORIENTAL.  DEB.             11.30.  627.27.
# 6  18 Jun 21.  ST MICHAELS SERVIC.  DEB.             52.94.  574.33.
# 7  18 Jun 21.          LEE CURRIE.  FPO.            409.00.  165.33.
# 8  18 Jun 21.          LEE CURRIE.  FPI.   50.00.            215.33.
# 9  18 Jun 21.         LNK BGL LTD.  CPT.             50.00.  165.33.

# %%
# Remove rows where column 0 has the value "Date" (with inplace=True)
df.drop(df[df['Date'].str.strip() == "Date."].index, inplace=True)
df.drop(df[df['Date'].str.strip() == "Date."].index, inplace=True)
df.drop(df[df['Date'].str.strip() == "Column"].index, inplace=True)
df.drop(df[df['Money In'].str.strip() == "Money In (£)\nblank."].index, inplace=True)
df.drop(df[df['Money Out'].str.strip() == "Money Out (£)\nblank."].index, inplace=True)
# Reset the index to maintain continuous indexing after dropping rows
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           Date          Description  Type                  Money In  \
# 0   16 Jun 21.  DUMFRIES HIGH ST (.  DEP.                   727.28.
# 1   17 Jun 21.      CONNOR GRIFFIN.  FPO.
# 2   17 Jun 21.      CONNOR GRIFFIN.  FPO.
# 3   18 Jun 21.          LEE CURRIE.  FPO.
# 4   18 Jun 21.       Sweet Sadie s.  DEB.
# 5   18 Jun 21.        NEW ORIENTAL.  DEB.
# 6   18 Jun 21.  ST MICHAELS SERVIC.  DEB.
# 7   18 Jun 21.          LEE CURRIE.  FPO.
# 8   18 Jun 21.          LEE CURRIE.  FPI.                    50.00.
# 9   18 Jun 21.         LNK BGL LTD.  CPT.
# 10  18 Jun 21.          LEE CURRIE.  FPI.                    50.00.
# 11  18 Jun 21.         LNK BGL LTD.  CPT.
# 12  18 Jun 21.          LEE CURRIE.  FPI.                    30.00.
# 13  18 Jun 21.         LNK BGL LTD.  CPT.
# 14  18 Jun 21.          LEE CURRIE.  FPI.                    30.00.
# 15  18 Jun 21.         LNK BGL LTD.  CPT.
# 16  21 Jun 21.  LEE CURRIE 19JUN21.  FPI.                   112.00.
# 17  21 Jun 21.  LNK CHURCH CRESCEN.  CPT.
# 18  21 Jun 21.              GREGGS.  DEB.
# 19  21 Jun 21.  WWW.PAYMENT-ASSIST.  DEB.
# 20  21 Jun 21.  SUMUP  *HELPINGHAN.  DEB.
# 21  21 Jun 21.  LNK DUMFRIES WHITE.  CPT.
# 22  21 Jun 21.      KFC - DUMFRIES.  DEB.
# 23  21 Jun 21.   TESCO STORES 2388.  DEB.
# 24  21 Jun 21.       CASTLE FRYERY.  DEB.
# 25  21 Jun 21.          DEAN POTTS.  FPO.
# 26  21 Jun 21.          LEE CURRIE.  FPI.                   250.00.
# 27  21 Jun 21.          DEAN POTTS.  FPO.
# 28  21 Jun 21.          DEAN POTTS.  FPO.
# 29  21 Jun 21.         LNK BGL LTD.  CPT.
# 30  22 Jun 21.  TESCO PAYAT PUMP 4.  DEB.
# 31  22 Jun 21.            CARLISLE.  DEB.
# 32  22 Jun 21.            CARLISLE.  DEB.
# 33  23 Jun 21.    MARCHBANK BAKERS.  DEB.
# 34  24 Jun 21.   REPORTCURVE.CO.UK.  DEB.
# 35  28 Jun 21.          TUI UK LTD.   DD.
# 36  28 Jun 21.         RETURNED DD.                         149.45.
# 37  30 Jun 21.          LEE CURRIE.  FPI.                    12.00.
# 38  30 Jun 21.      CONNOR GRIFFIN.  FPO.
# 39        BGC.    Bank Giro Credit.   BP.            Bill Payments.
# 40        DEP.             Deposit.  FEE.             Fixed Service
# 41        MPI.   Mobile Payment In.        MPO. Mobile Payment Out.
# 42        TFR.            Transfer.
#
#                    Money Out   Balance
# 0                              684.37.
# 1                     10.00.   674.37.
# 2                     10.00.   664.37.
# 3                     15.00.   649.37.
# 4                     10.80.   638.57.
# 5                     11.30.   627.27.
# 6                     52.94.   574.33.
# 7                    409.00.   165.33.
# 8                              215.33.
# 9                     50.00.   165.33.
# 10                             215.33.
# 11                    50.00.   165.33.
# 12                             195.33.
# 13                    30.00.   165.33.
# 14                             195.33.
# 15                    30.00.   165.33.
# 16                             277.33.
# 17                    10.00.   267.33.
# 18                     5.75.   261.58.
# 19                    60.08.   201.50.
# 20                    70.00.   131.50.
# 21                    60.00.    71.50.
# 22                     7.10.    64.40.
# 23                    10.48.    53.92.
# 24                    13.50.    40.42.
# 25                    10.00.    30.42.
# 26                             280.42.
# 27                    30.00.   250.42.
# 28                    10.00.   240.42.
# 29                    30.00.   210.42.
# 30                    37.18.   173.24.
# 31                    40.00.   133.24.
# 32                    94.00.    39.24.
# 33                     4.80.    34.44.
# 34                    29.25.     5.19.
# 35                   149.45.  -144.26.
# 36                               5.19.
# 37                              17.19.
# 38                    17.00.     0.19.
# 39              CHG. Charge.
# 40  FPI.\nFaster Payment In.      FPO.
# 41            PAY.\nPayment.       SO.
# 42

# %%
# Function to validate and convert dates
def is_valid_date(date_str):
    try:
        pd.to_datetime(date_str, format='%d %b %y')
        return True
    except ValueError:
        return False

# Remove trailing periods and check date validity
df['Date'] = df['Date'].str.replace('.', '', regex=False)
df['Date_valid'] = df['Date'].apply(is_valid_date)

# Filter out rows with invalid dates
df = df[df['Date_valid']].drop(columns='Date_valid')
df.tail(10)
# Out:
#          Date          Description  Type Money In Money Out   Balance
# 29  21 Jun 21         LNK BGL LTD.  CPT.             30.00.   210.42.
# 30  22 Jun 21  TESCO PAYAT PUMP 4.  DEB.             37.18.   173.24.
# 31  22 Jun 21            CARLISLE.  DEB.             40.00.   133.24.
# 32  22 Jun 21            CARLISLE.  DEB.             94.00.    39.24.
# 33  23 Jun 21    MARCHBANK BAKERS.  DEB.              4.80.    34.44.
# 34  24 Jun 21   REPORTCURVE.CO.UK.  DEB.             29.25.     5.19.
# 35  28 Jun 21          TUI UK LTD.   DD.            149.45.  -144.26.
# 36  28 Jun 21         RETURNED DD.        149.45.               5.19.
# 37  30 Jun 21          LEE CURRIE.  FPI.   12.00.              17.19.
# 38  30 Jun 21      CONNOR GRIFFIN.  FPO.             17.00.     0.19.

# %%
# Function to clean trailing periods from numerical values
def clean_numeric_values(value):
    if isinstance(value, str):
        return value.strip('.')
    return value

# Apply the cleaning function to relevant columns
columns_to_clean = ["Money In", "Money Out", "Balance"]
for column in columns_to_clean:
    df[column] = df[column].apply(clean_numeric_values)

# Convert columns to numeric types if needed
df["Money In"] = pd.to_numeric(df["Money In"], errors='coerce')
df["Money Out"] = pd.to_numeric(df["Money Out"], errors='coerce')
df["Balance"] = pd.to_numeric(df["Balance"], errors='coerce')

# %%
df
# Out:
#          Date          Description  Type  Money In  Money Out  Balance
# 0   16 Jun 21  DUMFRIES HIGH ST (.  DEP.    727.28        NaN   684.37
# 1   17 Jun 21      CONNOR GRIFFIN.  FPO.       NaN      10.00   674.37
# 2   17 Jun 21      CONNOR GRIFFIN.  FPO.       NaN      10.00   664.37
# 3   18 Jun 21          LEE CURRIE.  FPO.       NaN      15.00   649.37
# 4   18 Jun 21       Sweet Sadie s.  DEB.       NaN      10.80   638.57
# 5   18 Jun 21        NEW ORIENTAL.  DEB.       NaN      11.30   627.27
# 6   18 Jun 21  ST MICHAELS SERVIC.  DEB.       NaN      52.94   574.33
# 7   18 Jun 21          LEE CURRIE.  FPO.       NaN     409.00   165.33
# 8   18 Jun 21          LEE CURRIE.  FPI.     50.00        NaN   215.33
# 9   18 Jun 21         LNK BGL LTD.  CPT.       NaN      50.00   165.33
# 10  18 Jun 21          LEE CURRIE.  FPI.     50.00        NaN   215.33
# 11  18 Jun 21         LNK BGL LTD.  CPT.       NaN      50.00   165.33
# 12  18 Jun 21          LEE CURRIE.  FPI.     30.00        NaN   195.33
# 13  18 Jun 21         LNK BGL LTD.  CPT.       NaN      30.00   165.33
# 14  18 Jun 21          LEE CURRIE.  FPI.     30.00        NaN   195.33
# 15  18 Jun 21         LNK BGL LTD.  CPT.       NaN      30.00   165.33
# 16  21 Jun 21  LEE CURRIE 19JUN21.  FPI.    112.00        NaN   277.33
# 17  21 Jun 21  LNK CHURCH CRESCEN.  CPT.       NaN      10.00   267.33
# 18  21 Jun 21              GREGGS.  DEB.       NaN       5.75   261.58
# 19  21 Jun 21  WWW.PAYMENT-ASSIST.  DEB.       NaN      60.08   201.50
# 20  21 Jun 21  SUMUP  *HELPINGHAN.  DEB.       NaN      70.00   131.50
# 21  21 Jun 21  LNK DUMFRIES WHITE.  CPT.       NaN      60.00    71.50
# 22  21 Jun 21      KFC - DUMFRIES.  DEB.       NaN       7.10    64.40
# 23  21 Jun 21   TESCO STORES 2388.  DEB.       NaN      10.48    53.92
# 24  21 Jun 21       CASTLE FRYERY.  DEB.       NaN      13.50    40.42
# 25  21 Jun 21          DEAN POTTS.  FPO.       NaN      10.00    30.42
# 26  21 Jun 21          LEE CURRIE.  FPI.    250.00        NaN   280.42
# 27  21 Jun 21          DEAN POTTS.  FPO.       NaN      30.00   250.42
# 28  21 Jun 21          DEAN POTTS.  FPO.       NaN      10.00   240.42
# 29  21 Jun 21         LNK BGL LTD.  CPT.       NaN      30.00   210.42
# 30  22 Jun 21  TESCO PAYAT PUMP 4.  DEB.       NaN      37.18   173.24
# 31  22 Jun 21            CARLISLE.  DEB.       NaN      40.00   133.24
# 32  22 Jun 21            CARLISLE.  DEB.       NaN      94.00    39.24
# 33  23 Jun 21    MARCHBANK BAKERS.  DEB.       NaN       4.80    34.44
# 34  24 Jun 21   REPORTCURVE.CO.UK.  DEB.       NaN      29.25     5.19
# 35  28 Jun 21          TUI UK LTD.   DD.       NaN     149.45  -144.26
# 36  28 Jun 21         RETURNED DD.          149.45        NaN     5.19
# 37  30 Jun 21          LEE CURRIE.  FPI.     12.00        NaN    17.19
# 38  30 Jun 21      CONNOR GRIFFIN.  FPO.       NaN      17.00     0.19

# %%
df = df.fillna('')

# %%
file_path = "F:/python project/Bank-of-Scotland-classic-vantage-3.csv"

# %%
df.to_csv(file_path, index=False)
